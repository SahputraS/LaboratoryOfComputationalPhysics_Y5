# %% [markdown]
# # OSEMN Exercises

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import numpy.random as npr
npr.seed(123)

# %% [markdown]
# 1\. Create a random list of number and then save it to a text file named "simple_data.txt"

# %%
import random
rr = random.sample(range(10, 30),10)
print(rr)
# Out:
# [11, 25, 20, 14, 29, 22, 17, 19, 26, 12]

# %%
with open("simple_data.txt", "w") as output:
    output.write(str(rr))

# %% [markdown]
# 2\. Create a random matrix of 5x5 and then save it to a text file named "data.txt"

# %%
aaa = npr.rand(5,5)

# %%
with open("data.txt", "w") as output:
    output.write(str(aaa))

# %%
with open("datass.txt", "w") as output:
    output.write()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-8908ec4485c9> in <module>
#       1 with open("datass.txt", "w") as output:
# ----> 2     output.write()
#
# TypeError: write() takes exactly one argument (0 given)

# %%
file_name = "/home/sahputrn/Downloads/LaboratoryOfComputationalPhysics_Y5-main (5)/datass.txt"

# mode can be specified for writing, reading or both
with open(file_name, mode='w') as f:
    # print-out the whole file
    # print (f.read()) 
    for line in f:
        ## print line by line
        line = aaa[1,1:]
        ## each line is a string, you need to split it yourself
        # for c in line.split(): print(c) # check the functionalities of the split() method
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-36-05d6e3968c7a> in <module>
#       5     # print-out the whole file
#       6     # print (f.read())
# ----> 7     for line in f:
#       8         ## print line by line
#       9         line = aaa[1,1:]
#
# UnsupportedOperation: not readable

# %% [markdown]
# 3\. Load the saved txt file of point 2 and convert it to a csv file (by hand)

# %%
import pandas as pd

read_file = pd.read_csv (r'/home/sahputrn/Downloads/LaboratoryOfComputationalPhysics_Y5-main (5)/data.txt')
read_file.to_csv (r'/home/sahputrn/Downloads/LaboratoryOfComputationalPhysics_Y5-main (5)/datadata.csv', index=None)

# %% [markdown]
# 4\. load the binary file named *credit_card.dat* and convert the data into the real credit-card number.
# Each line correspond to a credit card number.
# Each character is composed by 6 bit (even the space) and the last 4 bit are just a padding
#
# **hint**: use the `chr()` function to convert a number to a char

# %%
data = np.loadtxt( 'credit_card.dat' )
print (data)
# Out:
# [1.10111110e+117 1.10011110e+117 1.10010110e+117 1.10000110e+117
#  1.10000110e+117 1.10101111e+117 1.10101110e+117 1.11000110e+117
#  1.10101110e+117 1.10110110e+117 1.10001110e+117 1.10111110e+117
#  1.10000110e+117 1.10001110e+117 1.10110110e+117 1.10111110e+117
#  1.10111110e+117 1.10010110e+117 1.10001110e+117 1.10000110e+117
#  1.10110110e+117 1.10001111e+117 1.10010110e+117 1.10101110e+117
#  1.10011110e+117 1.10100110e+117 1.10111110e+117 1.11000110e+117
#  1.10000110e+117 1.10101110e+117 1.10010110e+117 1.10010110e+117
#  1.10101111e+117 1.10000110e+117 1.10101111e+117 1.10010111e+117
#  1.10101110e+117 1.10001110e+117 1.11000110e+117 1.10100110e+117
#  1.10111110e+117 1.10010110e+117 1.10011110e+117 1.10001110e+117
#  1.10111110e+117 1.10000110e+117 1.10000110e+117 1.10010110e+117
#  1.11000110e+117 1.10011110e+117 1.01000000e+003]

# %%
# abb = "1101111101101101001110001"

# # ascii_string = "".join([chr(int(binary, 2)) for binary in abb.split(" ")])

# print (chr(int(abb)))

print(chr(1101111101101101001110001))
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-89-66ca49927a87> in <module>
#       5 # print (chr(int(abb)))
#       6
# ----> 7 print(chr(1101111101101101001110001))
#
# OverflowError: Python int too large to convert to C long

# %%
fh = open("/home/sahputrn/Downloads/LaboratoryOfComputationalPhysics_Y5-main (5)/credit_card.dat", "rb")

np.fromfile(fh, dtype=int)
# Out:
# array([3544668469065691441, 3544386994072269104, 3472328300539490352,
#        3544667365242318897, 3544386994088980784, 3544668464770789425,
#        3472610875010986289, 3472329400034275376, 3544668464770789681,
#        3544668469065691441, 3472328300539425072, 3472609771221233712,
#        3544667369537286449, 3472329400051118384, 3533689845445636400,
#        3472610875027763249, 3472609775516135728, 3544668469048979761,
#        3544668464753946672, 3544385894577352752, 3544385894560641328,
#        3472329400051118129, 3544385894577352752, 3544668464754012465,
#        3472610875011051569, 3472328296244457521, 3544386989777301808,
#        3472610870732795953, 3544667369554063665, 3544625583817240880,
#        3544386994072268848, 3472609771221233969, 3472609775499358513,
#        3472329400034275376, 3472328296244523056, 3544667365242319153,
#        3472328300539424816, 3472329395756150832, 3544667365242319153,
# ...

# %% [markdown]
# 5\. Load the file "user_data.json", filter the data by the "CreditCardType" field equals to "American Express". Than save the data a to CSV.

# %% [markdown]
# 6\. Load the file from this url: [https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1](https://www.dropbox.com/s/7u3lm737ogbqsg8/mushrooms_categorized.csv?dl=1) with Pandas.
# + Explore the data (see the info of the data)
# + Draw the istogram of the 'class' field. Decribe wath yuou see

# %% [markdown]
# 7\. Load the remote file [https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1](https://www.dropbox.com/s/vkl89yce7xjdq4n/regression_generated.csv?dl=1) with Pandas and plot a scatter plot all possible combination of the following fields:
#
#   + features_1
#   + features_2
#   + features_3

# %% [markdown]
# 8\. Load the same file of point 6, and convert the file to json with Pandas.
